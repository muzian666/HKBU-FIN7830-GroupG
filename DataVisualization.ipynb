# %% [markdown]
# # Load Dataset

# %% [markdown]
# ## Import Original Dataset

# %%
import pandas as pd

file_path = 'HR_Analytics.csv.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ## Import Balanced Dataset

# %%
import pandas as pd

file_path = 'Balanced_HR_Analytics.csv'
df = pd.read_csv(file_path)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the visualization style
sns.set(style="whitegrid")

# Create a list of numeric and categorical columns
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

# Create subplots for numeric data
fig, axes = plt.subplots(len(numeric_cols)//3, 3, figsize=(18, 24))

for col, ax in zip(numeric_cols, axes.flatten()):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(f'Distribution of {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# Create bar plots for categorical data
fig, axes = plt.subplots(len(categorical_cols), 1, figsize=(18, 24))

for col, ax in zip(categorical_cols, axes.flatten()):
    sns.countplot(data=df, x=col, ax=ax)
    ax.set_title(f'Distribution of {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 24
#      21 plt.show()
#      23 # Create bar plots for categorical data
# ---> 24 fig, axes = plt.subplots(len(categorical_cols), 1, figsize=(18, 24))
#      26 for col, ax in zip(categorical_cols, axes.flatten()):
#      27     sns.countplot(data=df, x=col, ax=ax)
#
# File ~\miniconda3\envs\class\Lib\site-packages\matplotlib\pyplot.py:1599, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1455 """
#    1456 Create a figure and a set of subplots.
#    1457
#    (...)
#    1596
#    1597 """
#    1598 fig = figure(**fig_kw)
# -> 1599 axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1600                    squeeze=squeeze, subplot_kw=subplot_kw,
#    1601                    gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1602                    width_ratios=width_ratios)
#    1603 return fig, axs
#
# File ~\miniconda3\envs\class\Lib\site-packages\matplotlib\figure.py:930, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw)
#     926         raise ValueError("'width_ratios' must not be defined both as "
#     927                          "parameter and as key in 'gridspec_kw'")
#     928     gridspec_kw['width_ratios'] = width_ratios
# --> 930 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#     931 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     932                   subplot_kw=subplot_kw)
#     933 return axs
#
# File ~\miniconda3\envs\class\Lib\site-packages\matplotlib\figure.py:1542, in FigureBase.add_gridspec(self, nrows, ncols, **kwargs)
#    1503 """
#    1504 Return a `.GridSpec` that has this figure as a parent.  This allows
#    1505 complex layout of Axes in the figure.
#    (...)
#    1538
#    1539 """
#    1541 _ = kwargs.pop('figure', None)  # pop in case user has added this...
# -> 1542 gs = GridSpec(nrows=nrows, ncols=ncols, figure=self, **kwargs)
#    1543 return gs
#
# File ~\miniconda3\envs\class\Lib\site-packages\matplotlib\gridspec.py:378, in GridSpec.__init__(self, nrows, ncols, figure, left, bottom, right, top, wspace, hspace, width_ratios, height_ratios)
#     375 self.hspace = hspace
#     376 self.figure = figure
# --> 378 super().__init__(nrows, ncols,
#     379                  width_ratios=width_ratios,
#     380                  height_ratios=height_ratios)
#
# File ~\miniconda3\envs\class\Lib\site-packages\matplotlib\gridspec.py:48, in GridSpecBase.__init__(self, nrows, ncols, height_ratios, width_ratios)
#      33 """
#      34 Parameters
#      35 ----------
#    (...)
#      45     If not given, all rows will have the same height.
#      46 """
#      47 if not isinstance(nrows, Integral) or nrows <= 0:
# ---> 48     raise ValueError(
#      49         f"Number of rows must be a positive integer, not {nrows!r}")
#      50 if not isinstance(ncols, Integral) or ncols <= 0:
#      51     raise ValueError(
#      52         f"Number of columns must be a positive integer, not {ncols!r}")
#
# ValueError: Number of rows must be a positive integer, not 0

# %%
# Explore the relationship between numerical features and the target variable 'Attrition'
fig, axes = plt.subplots(len(numeric_cols)//3, 3, figsize=(18, 24))

for col, ax in zip(numeric_cols, axes.flatten()):
    sns.boxplot(data=df, x='Attrition', y=col, ax=ax)
    ax.set_title(f'{col} vs Attrition')
    ax.set_xlabel('Attrition')
    ax.set_ylabel(col)

plt.tight_layout()
plt.show()

# Explore the relationship between categorical features and the target variable 'Attrition'
fig, axes = plt.subplots(len(categorical_cols)-1, 1, figsize=(18, 24))  # Exclude 'Attrition' itself

for col, ax in zip(categorical_cols[:-1], axes.flatten()):  # Exclude 'Attrition' itself
    sns.countplot(data=df, x=col, hue='Attrition', ax=ax)
    ax.set_title(f'{col} vs Attrition')
    ax.set_xlabel(col)
    ax.set_ylabel('Count')

plt.tight_layout()
plt.show()
